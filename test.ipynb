# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test.csv')

# %%
df
# Out:
#       Time:512Hz  Epoch  Electrode  Attention  Meditation   Delta    Theta  \
# 0       0.000000      0      101.0       51.0        64.0  9068.0   7242.0
# 1       0.001953      0      101.0       51.0        64.0  9068.0   7242.0
# 2       0.003906      0       87.0       51.0        64.0  9068.0   7242.0
# 3       0.005859      0       72.0       51.0        64.0  9068.0   7242.0
# 4       0.007812      0       67.0       51.0        64.0  9068.0   7242.0
# ...          ...    ...        ...        ...         ...     ...      ...
# 8763   17.115234    273      232.0       80.0        41.0  2415.0  12054.0
# 8764   17.117188    273      244.0       80.0        41.0  2415.0  12054.0
# 8765   17.119141    273      220.0       80.0        41.0  2415.0  12054.0
# 8766   17.121094    273      185.0       80.0        41.0  2415.0  12054.0
# 8767   17.123047    273      161.0       80.0        41.0  2415.0  12054.0
#
# ...

# %%
df[df['Event Id'].notna()]
# Out:
#       Time:512Hz  Epoch  Electrode  Attention  Meditation    Delta    Theta  \
# 3584     7.00000    112       59.0       26.0        47.0   5399.0   2796.0
# 3840     7.50000    120       67.0       26.0        47.0   5399.0   2796.0
# 4640     9.06250    145       39.0       50.0        66.0  17964.0  10480.0
# 4704     9.18750    147       51.0       50.0        66.0  17964.0  10480.0
# 4912     9.59375    153       77.0       50.0        66.0  17964.0  10480.0
# 4976     9.71875    155       64.0       50.0        66.0  17964.0  10480.0
# 6304    12.31250    197       57.0       77.0        57.0   1834.0   1383.0
# 6384    12.46875    199       99.0       77.0        57.0   1834.0   1383.0
# 6736    13.15625    210       59.0       75.0        53.0  56344.0  15819.0
# 6816    13.31250    213      130.0       75.0        53.0  56344.0  15819.0
# 7040    13.75000    220      106.0       75.0        53.0  56344.0  15819.0
# ...

# %%
df = df[df['obs'] != '*']      #drop rows with all null
df.reset_index(inplace=True)
df
# Out:
#      index  obs   time     Delta    Theta   Alpha1   Alpha2    Beta1   Beta2  \
# 0        0    1    5.0   24821.0  23964.0   1674.0   1971.0   1541.0  1932.0
# 1        2    2    6.0    9350.0  11686.0   2673.0   4754.0   9706.0  5352.0
# 2        4    3    7.0   98750.0   4341.0   2094.0   1808.0   2267.0  1848.0
# 3        6    4    8.0  685460.0  64285.0  20885.0  17957.0   7212.0  7764.0
# 4        8    5    9.0   12188.0  15633.0   4169.0   1689.0   2481.0  1065.0
# ..     ...  ...    ...       ...      ...      ...      ...      ...     ...
# 142    284  143  147.0   24339.0  17486.0   2993.0   1217.0   3864.0  1656.0
# 143    286  144  148.0   33823.0   8700.0  12973.0   9308.0   4773.0  2846.0
# 144    288  145  149.0   20089.0  22797.0  20871.0   6630.0   2050.0  6440.0
# 145    290  146  150.0   11120.0   2821.0   2533.0   3875.0   1430.0  1909.0
# 146    292  147  150.0   30773.0  14667.0   5586.0   6829.0  14511.0  9214.0
#
# ...

# %%
df = df[df[' Alpha1'] < 50000]        #drop weirdly high data

# %%
plt.figure(figsize=(14,8))
plt.plot(df[' Alpha1'])
plt.plot(df[' Alpha2'])
plt.show()

# %%
attention = df[' Attention'][3:]
attention = attention.astype(float)

meditation = df[' Meditation'][3:]
meditation = meditation.astype(float)

# %%
plt.figure(figsize=(14,8))
plt.plot(attention)
plt.plot(meditation)
plt.show()
