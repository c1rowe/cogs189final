# %% [markdown]
# ## COGS 189 Final Project: Where's Waldo?
# Code and analysis of data obtained from Mindwave experiment

# %%
import pandas as pd
import numpy as np
import os
from os import listdir
from os.path import isfile, join, isdir
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy import signal
import scipy.fftpack
import statsmodels.api as sm

# %% [markdown]
# ### Global Variables

# %%
sampling_rate = 512.0
epoch_length = 7.0

step = 100
maxamp = 750000
wavemax = int(maxamp/step)

# %% [markdown]
# ### Helper Functions
# #### Functions for Epoching Data

# %%
#
# Cleans a given raw openvibe dataframe
#
def clean_trial(trial):
    
    #drop unwanted columns
    trial = trial.drop(columns=['Event Duration'])
    trial = trial.drop(columns=['Event Date'])
    trial = trial.drop(columns=['Electrode'])
    
    #remove nans and key releases
    trial.loc[trial['Event Id'] == 33024,  'Event Id'] = 0
    trial.loc[trial['Event Id'].isnull(),  'Event Id'] = 0
    
    #shift df to start on start key press
    start_index = trial.index[trial['Event Id'] == 33025]
    trial = trial[(start_index[0]+1):].reset_index()
    trial = trial.drop(columns=['index'])
    
    #reset epoch to begin at 0/drop epoch column
    #trial = trial.drop(columns=['Epoch'])
    trial['Epoch']-=trial['Epoch'][0]
    
    #reset time to begin at 0
    trial['Time:512Hz']-=trial['Time:512Hz'][0]
    
    #set found waldo id 1
    trial.loc[trial['Event Id'] == 33027,  'Event Id'] = 1
    
    #rename columns as needed
    trial = trial.rename(columns={"Time:512Hz": "Time", "Event Id": "Event"})
    
    #cut end of data
    found_times = trial.loc[trial['Event'] == 1,'Time'].tolist()
    
    end_index = trial.index[trial['Time'] == found_times[len(found_times)-1]][0]
    trial = trial[0:end_index+1]
    
    
    return trial

# %%
#
# Reads and cleans the csv file at the given filepath
#
def processcsv(filename):
    raw = pd.read_csv(filename)
    clean = clean_trial(raw)
    return clean

# %%
#
# For/If we need to filter
#
def custom_filter(trial):
    print("Filter not implemented yet")

# %%
#
# Takes in the cleaned up data and returns an array.
# Each entry of the array has a pandas dataframe corresponding to a trial,
# Where a trial ends the moment the 'found' key was pressed. 
# At that time the next stage begins
#
def split_trials(trial):
    
    final_split = []
    found_times = trial.loc[trial['Event'] == 1,'Time'].tolist()
    
    start = 0;
    end = found_times[0]
    
    for i in range(0,len(found_times)):
        
        start_index = trial.index[trial['Time'] == start][0]
        end_index = trial.index[trial['Time'] == end][0]
        
        curr_trial = trial.loc[start_index+1:end_index+1].reset_index()     #changed this line
        curr_trial = curr_trial.drop(columns=['index'])
        curr_trial['Time']-=curr_trial['Time'][0]
        
        final_split.append(curr_trial.copy())
        
        start = end;
        if(i<len(found_times)-1):
            end = found_times[i+1]
        
    return final_split

# %%
#
# Takes in a trial and completes the 'Epoch' column, starting at the 'start_epoch' parameter
# This parameter is default at 0, so the trial will start at epoch 0 and so on.
# Every epoch is of length 'epoch_length', defined at the top of the notebook
# The epoch corresponding to the found stage has its 'Event' column set to 1 (facilitates extraction)
#
def single_epoch(trial, start_epoch):
    
    end_time = trial['Time'][len(trial)-1]
    start_time = trial['Time'][0]
    #print(end_time)
    #print(start_time)
    num_epochs = int((end_time-start_time)/epoch_length)
    
    #print(num_epochs)
    
    event_epoch = start_epoch + num_epochs -1
    last_epoch =  start_epoch + num_epochs -1
    trial.loc[trial['Time'] <= (end_time),'Epoch'] = last_epoch
    last_epoch-=1
    
        
    limit = end_time - epoch_length
    if limit >= epoch_length:
        while(limit >= 0):
            trial.loc[trial['Time'] < (limit),'Epoch'] = last_epoch
            last_epoch-=1
            limit -= epoch_length
        
        limit += epoch_length
    
    trial = trial[trial['Time'] > limit]
    trial.loc[trial['Epoch'] == event_epoch,'Event'] = 1
    trial = trial.reset_index()
    trial = trial.drop(columns=['index'])
    
    trial['Time']-=trial['Time'][0]
    
    return trial

# %%
#
# Takes in all trials and epochs them with the 'single_epoch' function
#
def epoch_trials(all_trials):
    for i in range(0,len(all_trials)):
        all_trials[i] = single_epoch(all_trials[i], 0)
    return all_trials

# %%
#
# Reduce dataframe to just brainwave cols
# Returns a dataframe with just the brainwave values out of a trial
#
def get_brainwaves(trial):
    return trial.drop(columns=['Time','Attention','Epoch', 'Meditation', 'Event'])

# %%
#
# Returns two arrays: (1) paths to trials, (2) names of trials
#
def get_files():
    
    file_names_ = []
    trial_labels_ = []
    for root, dirs, files in os.walk("./trials"):
        for filename in files:
            file_names_.append('./trials/' + filename)
            trial_name = filename.split(".")[0]
            trial_labels_.append(trial_name)
    return file_names_, trial_labels_

# %%
#
# Applies and returns 'processcsv' in all profided filepaths
#
def process_trials (filepaths, labels_):
    all_trials_ = []
    i=0
    for f in filepaths:
        all_trials_.append(processcsv(f))
        print('Processed ' + str(labels_[i]))
        i+=1
    
    return all_trials_

# %%
def split_epoch_trials(trials_, labels_):
    
    s_e_trials_ = []
    i=0
    for t in trials_:
        trials = split_trials(t)
        epoched_trials = epoch_trials(trials)
        
        s_e_trials_.append(epoched_trials)
        print('Split and epoched ' + str(labels_[i]))
        i+=1
    
    return s_e_trials_

    # Epochs the split up trials into epochs of length 'epoch_length' defined on top of the document
    # The epoch corresponding to the found stage has its 'Event' column set to 1
    epoched_trials = epoch_trials(trials)

# %% [markdown]
# #### Functions for Averaging Brainwave Densities

# %%
def average_densities(raw_df):
    '''
    Generate average densities of amplitudes across brainwave types. Also stack densities of each brainwave into density_matrix.
    
    Params:
    raw_df(DataFrame): Raw brainwave values (amplitudes)
    max_amp(int): Max amplitude to calculate densities up to
    
    Returns:
    mean_vector(ndarray): 1x(maxamp/step) vector. Index represents given amplitude, value represents density of given amplitude.
    density_matrix(ndarray) : 8x(maxamp/step) matrix. 
                              density_matrix(i,j) == density of amplitude j within brainwave type i
    '''

    # matrix to contain all densities
    # let rows == wave type, columns == pdf generated density Y at X amplitude (for given wave)
    density_matrix = np.empty([8,int(wavemax)])

    # iterate across all wave types and stack each wave type density as rows in density_matrix
    # wave type density is a 75,000 value list. each value represents the density of waves at [index] frequency
    for i in range(0, raw_df.shape[1]):
        print("Calculating density for wave " + str(i+1) + "/8")
        # potential optimization: clear repeating values in original df
        density = stats.gaussian_kde(raw_df.iloc[0:,i], bw_method='scott')
        density_matrix[i] = list(density.pdf(range(0,maxamp,step)))     # potential optimization: increase step width

    # now find the total average densities for all wave types, 
    # column wise (end with 1x75000 vector) that reprents overall behavior
    mean_vector = np.mean(density_matrix, axis=0)
    
    return mean_vector, density_matrix

# %%
def plot_avg(mean_vectors, labels, title, x_max=17000, fig_x=14, fig_y=8):
    '''
    Plot mean density of each amplitude. Not trivial because average_densities compresses the original densities by a factor of
    step.
    
    Params:
    mean_vector(ndarray): 1x(maxamp/step) vector. Index represents given amplitude, value represents density of given amplitude.
    x_max(int): Max value to show on plot x-axis.
    fig_x(int): X dimension of figure generated
    fig_y(int): Y dimension of figure generated
    '''
    
    #generate plot
    plt.figure(figsize=(fig_x,fig_y))
        
    i = 0
    for v in mean_vectors:
    
        # must create accurate x-axis vector (stretch by factor of step)
        x_axis = list(range(0,wavemax))
        x_axis = [x * step for x in x_axis]

        plt.plot(x_axis, v, label = str(labels[i]))
        i+=1
    
    plt.title(str(title) + ' mean density across brainwaves')
    plt.legend()    
    plt.ylabel('Density')
    plt.xlabel('Frequencies')
    plt.xlim(0, x_max)

# %%
def densityframe(density_matrix):
    '''
    Build dataframe of densities from density_matrix with brainwave distinctions intact.
    
    Params:
    density_matrix(ndarray): 8x(maxamp/step) matrix to build from. 
                            density_matrix(i,j) == density of amplitude j within brainwave type i
                            
    Return:
    density_df(DataFrame): Dataframe with amplitude/step on rows, brainwave types on columns.
    '''
    density_df = pd.DataFrame(density_matrix, 
                              index=['Delta','Theta','Low Alpha','High Alpha','Low Beta','High Beta','Low Gamma','Mid Gamma'])
    density_df = density_df.transpose()
    density_df['True Amplitude'] = (density_df.index + 1) * step
    
    return density_df

# %% [markdown]
# ### Automatizing testing all trials
# In this section, data from trial csv files are processed, split, and epoched into 10-second intervals centered around searching for Waldo phases and phases in which Waldo was found.

# %%
# Get trial paths and names
# (windows ver.)
filenames =  ['alberto_trial.csv', 'cece_trial.csv', 'chase_trial.csv', 'huiyu_trial.csv', 
              'waldorecording_ahsan1.csv', 'waldorecording_ahsan2.csv']
trial_labels = ['alberto','cece','chase','huiyu','ahsan','isaac']

# %%
# Read and process all trials
all_trials = process_trials(filenames,trial_labels)
# Out:
# Processed alberto
# Processed cece
# Processed chase
# Processed huiyu
# Processed ahsan
# Processed isaac

# %%
# Split and epoch all trials
s_e_trials = split_epoch_trials(all_trials, trial_labels)
# Out:
# Split and epoched alberto
# Split and epoched cece
# C:\Users\Me\Anaconda3\lib\site-packages\pandas\core\indexing.py:964: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Split and epoched chase
# Split and epoched huiyu
# Split and epoched ahsan
# Split and epoched isaac

# %%
# create list to store brainwave only dfs from trials in SEARCH and FOUND phase
search_lists = []
found_lists = []

for epoched_tr_ in s_e_trials:
    search_list_ = [get_brainwaves(trial[trial['Event'] == 0.0]) for trial in epoched_tr_]
    found_list_ = [get_brainwaves(trial[trial['Event'] == 1.0]) for trial in epoched_tr_]
    search_lists.append(search_list_)
    found_lists.append(found_list_)

# %% [markdown]
# ### Density Calculation
# Next, densities of each wave across amplitudes was calculated and stored. This was done individually for all trials associated with each person.
#
# The "overall" average density was also calculated by taking the mean across all brainwave types.

# %%
# Average search lists
search_means = []
search_density_mats = []

for sl in search_lists:
    search_mean_, search_density_mat_ = average_densities(sl[0])
    search_means.append(search_mean_)
    search_density_mats.append(search_density_mat_)
# Out:
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8

# %%
# Average search lists
found_means = []
found_density_mats = []

for fl in found_lists:
    found_mean_, found_density_mat_ = average_densities(fl[0])
    found_means.append(found_mean_)
    found_density_mats.append(found_density_mat_)
# Out:
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8
# Calculating density for wave 1/8
# Calculating density for wave 2/8
# Calculating density for wave 3/8
# Calculating density for wave 4/8
# Calculating density for wave 5/8
# Calculating density for wave 6/8
# Calculating density for wave 7/8
# Calculating density for wave 8/8

# %% [markdown]
# ### Plotting Density Curves
# #### Mean Densities
# Generated densities were plotted for each person with search stage and found stage separate. These curves represent the overall mean density calculated in the previous step.

# %%
#plotting
if((len(found_means)) != (len(search_means))):
    print("ERROR")

for i in range(0,len(found_means)):
    plot_avg(mean_vectors=[search_means[i],found_means[i]], labels=['Search Stage', 'Found Stage'], title=trial_labels[i])

# %% [markdown]
# Finally, the mean density across all participants was calculated by taking the average of the above densities. Note that this should represent the same density that we would have obtained had we calculated using all the original data points at once, as each set of data that went into calculating this final mean had the same sample size.

# %%
final_search = sum(search_means)/len(search_means)
final_found = sum(found_means)/len(found_means)

plot_avg(mean_vectors=[final_search, final_found], labels=['Search Stage', 'Found Stage'], title='Final Overall', x_max=75000)

# %% [markdown]
# #### Densities by Brainwave Type
# Because some information is lost in taking the overall mean, we also took the mean across participants by brainwave type (i.e. keeping brainwave columns distinct). The plots below represent the average frequency densities across participants for each brainwave type.

# %%
mean_search_den = sum(search_density_mats)/len(search_density_mats)
mean_found_den = sum(found_density_mats)/len(found_density_mats)

search_df = densityframe(mean_search_den)
found_df = densityframe(mean_found_den)

#found_density_df.iloc[:,:-1].plot(figsize=(14,8))

search_df.iloc[:,:-1].plot(figsize=(14,8))
plt.title("Overall Average Density by Brainwave Type, Search Phase")
plt.xlabel("Frequency (/100)")
plt.ylabel("Density")
plt.xlim(0,550)
plt.show()

found_df.iloc[:,:-1].plot(figsize=(14,8))
plt.title("Overall Average Density by Brainwave Type, Found Phase")
plt.xlabel("Frequency (/100)")
plt.ylabel("Density")
plt.xlim(0,550)
plt.show()

# %%
cols = list(search_df.columns)[0:len(list(search_df.columns))-1] 
for c in cols:
    search_df[c].plot(figsize=(14,8), label ='search')
    found_df[c].plot(figsize=(14,8),label ='found')
    plt.title(c)
    plt.legend()
    plt.xlim(0,550)
    plt.show()

# %% [markdown]
# ### Welch Windowing and FFT Plots

# %%
#try Welch windowing

fs = 512
N = len(found_means)

cols = list(found_df.columns)[0:len(list(found_df.columns))-1] 
for c in cols:
    print(c)
    
    f, t = signal.welch(found_df[c], fs, nperseg = 1024)
    f_search, t_search = signal.welch(search_df[c], fs, nperseg = 1024)
    plt.semilogy(f, t, label = 'Found')
    plt.semilogy(f_search,t_search, label = 'Search')
    plt.legend()
    plt.xlabel('frequency [Hz]')
    plt.ylabel('PSD [V**2/Hz]')
    plt.show()
# Out:
# Delta
# Theta
# Low Alpha
# High Alpha
# Low Beta
# High Beta
# Low Gamma
# Mid Gamma

# %%
def compute_power_spectrum(x_a):
    return np.abs(x_a)**2, np.angle(x_a)
    
def fft(signal_name, signal_1, signal_2, sampling_rate):
    
    fs = 1/sampling_rate
    N_1 = signal_1.size
    N_2 = signal_2.size
    
    y1 = signal_1.values
    yf1 = scipy.fft(y1)
    
    y2 = signal_2.values
    yf2 = scipy.fft(y2)
    
    x1 = scipy.fftpack.fftfreq(yf1.size, fs)
    xf1 = scipy.fftpack.fftfreq(N_1, d = fs)
    
    x2 = scipy.fftpack.fftfreq(yf2.size, fs)
    xf2 = scipy.fftpack.fftfreq(N_2, d = fs)

    fid, ax = plt.subplots()
    ax.plot(x1[:x1.size//2], abs(yf1)[:yf1.size//2], label = 'Search')
    ax.plot(x2[:x2.size//2], abs(yf2)[:yf2.size//2], label='Found')
    plt.xlim(0,2)
    plt.legend()
    plt.title('{} FFT'.format(signal_name))
    plt.xlabel('Frequency');plt.ylabel('Phase')
    plt.show()
    
    return x1, yf1 , x2, yf2
    
    
def plot_power_spectrum(signal_name, signal1, signal2):
    plt.figure(figsize=(20,3))
        
    fs=512
    freqs_search, phasor_search, freqs_found, phasor_found= fft(signal_name,signal1, signal2,fs)

    power_search, phase_search = compute_power_spectrum(phasor_search)
    power_found, phase_found = compute_power_spectrum(phasor_found)
    
    plt.plot(freqs_search, power_search, '.', label = 'Search')
    plt.plot(freqs_found, power_found, '.', label = 'Found')
    
    
    plt.xlim([0,8])
    plt.legend()
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power (mV^2)')
    #plt.ylim([0,2])
    plt.title('{} power spectrum'.format(signal_name))

# %%
for c in cols: 
    plot_power_spectrum(c, search_df[c], found_df[c])

# %% [markdown]
# ### Statistical Tests
# Finally, we ran statistical tests of significance to determine if brainwave distributions were significantly different in the search and found phase. Because the same set of amplitudes was to be tested in both phases, we treated the data as paired and used a paired t-test to determine if there was a significant change in amplitude densities overall.

# %%
# replace index with true amp col
search_df.index = search_df['True Amplitude']
search_df.drop(['True Amplitude'], inplace=True, axis=1)
found_df.index = found_df['True Amplitude']
found_df.drop(['True Amplitude'], inplace=True, axis=1)

# %% [markdown]
# As the paired t-test relies on the assumption that the differences between samples lie on a normal distribution, we plotted the histograms of sample differences below. The histograms show a roughly normal distribution for all sample differences, albeit with very low standard deviation.

# %%
# check normality of differences to satisfy assumptions for t-test
diff_df = search_df['Delta'] - found_df['Delta']
diff_df.plot.hist(figsize=(14,8), bins=15)

for i in range(search_df.shape[1]):
    diff = search_df.iloc[:,i] - found_df.iloc[:,i]
    diff.plot.hist(figsize=(14,8), bins=15)
    plt.show()

# %%
total_diff = final_search - final_found

plt.figure(figsize=(14,8))
plt.hist(total_diff, bins=15)
plt.show()

# %% [markdown]
# Now we perform the paired t-test with $p = 0.10$; we will conclude that there was a significant difference between phases if the observed p-value < 0.10.

# %%
# perform dependent t-test on each brainwave, as well as overall density
for i in range(search_df.shape[1]):
    print(search_df.iloc[:,i].name + ': ')
    print(stats.ttest_rel(search_df.iloc[:,i], found_df.iloc[:,i], axis=0))
    
print('Overall density: ')
print(stats.ttest_rel(final_search, final_found, axis=0))
# Out:
# Delta:
# Ttest_relResult(statistic=11.735121797737774, pvalue=1.5868702443027942e-31)
# Theta:
# Ttest_relResult(statistic=1.5940597857219192, pvalue=0.11096478790051244)
# Low Alpha:
# Ttest_relResult(statistic=0.17050220168087815, pvalue=0.8646198027512327)
# High Alpha:
# Ttest_relResult(statistic=0.13711399635679894, pvalue=0.8909443703974596)
# Low Beta:
# Ttest_relResult(statistic=1.8289922395789162, pvalue=0.06744046289036801)
# High Beta:
# Ttest_relResult(statistic=0.12179519041349368, pvalue=0.903064486510534)
# Low Gamma:
# Ttest_relResult(statistic=1.0642575866905104, pvalue=0.287246293001748)
# Mid Gamma:
# Ttest_relResult(statistic=0.2129932217107004, pvalue=0.8313380393253091)
# Overall density:
# Ttest_relResult(statistic=1.7552197370544886, pvalue=0.07926255811839579)

# %% [markdown]
# Only Delta, Low Beta, and Overall density was significant with $p = 0.10.$

# %% [markdown]
# ### OLS Regression

# %%
for c in cols:
    model = sm.OLS(endog = found_df[c], exog = np.arange(7500))
    res = model.fit()
    
    print('{} Model Summary'.format(c))
    print(res.summary())
    print('\n\n\n\n\n')
# Out:
# Delta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Delta   R-squared (uncentered):                   0.111
# Model:                            OLS   Adj. R-squared (uncentered):              0.111
# Method:                 Least Squares   F-statistic:                              935.7
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                   9.21e-194
# Time:                        14:05:51   Log-Likelihood:                          92228.
# No. Observations:                7500   AIC:                                 -1.845e+05
# Df Residuals:                    7499   BIC:                                 -1.844e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          9.012e-11   2.95e-12     30.590      0.000    8.43e-11    9.59e-11
# ==============================================================================
# Omnibus:                     1109.264   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1663.839
# Skew:                           1.134   Prob(JB):                         0.00
# Kurtosis:                       3.420   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Theta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Theta   R-squared (uncentered):                   0.006
# Model:                            OLS   Adj. R-squared (uncentered):              0.006
# Method:                 Least Squares   F-statistic:                              42.57
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                    7.28e-11
# Time:                        14:05:51   Log-Likelihood:                          85164.
# No. Observations:                7500   AIC:                                 -1.703e+05
# Df Residuals:                    7499   BIC:                                 -1.703e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           4.93e-11   7.56e-12      6.524      0.000    3.45e-11    6.41e-11
# ==============================================================================
# Omnibus:                     4340.662   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29011.978
# Skew:                           2.839   Prob(JB):                         0.00
# Kurtosis:                      10.785   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Low Alpha Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Low Alpha   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.8057
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.369
# Time:                        14:05:51   Log-Likelihood:                          79871.
# No. Observations:                7500   AIC:                                 -1.597e+05
# Df Residuals:                    7499   BIC:                                 -1.597e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.374e-11   1.53e-11      0.898      0.369   -1.63e-11    4.37e-11
# ==============================================================================
# Omnibus:                     8442.442   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           540137.359
# Skew:                           6.048   Prob(JB):                         0.00
# Kurtosis:                      42.776   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# High Alpha Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             High Alpha   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.1377
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.711
# Time:                        14:05:51   Log-Likelihood:                          77422.
# No. Observations:                7500   AIC:                                 -1.548e+05
# Df Residuals:                    7499   BIC:                                 -1.548e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          7.872e-12   2.12e-11      0.371      0.711   -3.37e-11    4.95e-11
# ==============================================================================
# Omnibus:                    10515.320   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2112618.637
# Skew:                           8.462   Prob(JB):                         0.00
# Kurtosis:                      83.461   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Low Beta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Low Beta   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.1270
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.722
# Time:                        14:05:51   Log-Likelihood:                          77580.
# No. Observations:                7500   AIC:                                 -1.552e+05
# Df Residuals:                    7499   BIC:                                 -1.552e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          7.402e-12   2.08e-11      0.356      0.722   -3.33e-11    4.81e-11
# ==============================================================================
# Omnibus:                     9618.348   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1068577.538
# Skew:                           7.391   Prob(JB):                         0.00
# Kurtosis:                      59.577   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# High Beta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              High Beta   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                            0.04642
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.829
# Time:                        14:05:51   Log-Likelihood:                          76025.
# No. Observations:                7500   AIC:                                 -1.520e+05
# Df Residuals:                    7499   BIC:                                 -1.520e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          5.506e-12   2.56e-11      0.215      0.829   -4.46e-11    5.56e-11
# ==============================================================================
# Omnibus:                    11038.319   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2795789.762
# Skew:                           9.211   Prob(JB):                         0.00
# Kurtosis:                      95.775   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Low Gamma Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Low Gamma   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                            0.01645
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.898
# Time:                        14:05:51   Log-Likelihood:                          74852.
# No. Observations:                7500   AIC:                                 -1.497e+05
# Df Residuals:                    7499   BIC:                                 -1.497e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          3.833e-12   2.99e-11      0.128      0.898   -5.47e-11    6.24e-11
# ==============================================================================
# Omnibus:                    12534.079   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7236795.186
# Skew:                          11.542   Prob(JB):                         0.00
# Kurtosis:                     153.416   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Mid Gamma Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Mid Gamma   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                           0.007231
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.932
# Time:                        14:05:51   Log-Likelihood:                          73750.
# No. Observations:                7500   AIC:                                 -1.475e+05
# Df Residuals:                    7499   BIC:                                 -1.475e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          2.943e-12   3.46e-11      0.085      0.932   -6.49e-11    7.08e-11
# ==============================================================================
# Omnibus:                    13947.755   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17527643.220
# Skew:                          14.173   Prob(JB):                         0.00
# Kurtosis:                     238.128   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for c in cols:
    model = sm.OLS(endog = search_df[c], exog = np.arange(7500))
    res = model.fit()
    
    print('{} Model Summary'.format(c))
    print(res.summary())
    print('\n\n\n\n\n')
# Out:
# Delta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Delta   R-squared (uncentered):                   0.071
# Model:                            OLS   Adj. R-squared (uncentered):              0.071
# Method:                 Least Squares   F-statistic:                              573.6
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                   3.33e-122
# Time:                        14:05:52   Log-Likelihood:                          90732.
# No. Observations:                7500   AIC:                                 -1.815e+05
# Df Residuals:                    7499   BIC:                                 -1.815e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          8.613e-11    3.6e-12     23.949      0.000    7.91e-11    9.32e-11
# ==============================================================================
# Omnibus:                     1667.063   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2998.032
# Skew:                           1.484   Prob(JB):                         0.00
# Kurtosis:                       3.884   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Theta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Theta   R-squared (uncentered):                   0.003
# Model:                            OLS   Adj. R-squared (uncentered):              0.003
# Method:                 Least Squares   F-statistic:                              22.72
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                    1.91e-06
# Time:                        14:05:52   Log-Likelihood:                          83714.
# No. Observations:                7500   AIC:                                 -1.674e+05
# Df Residuals:                    7499   BIC:                                 -1.674e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           4.37e-11   9.17e-12      4.767      0.000    2.57e-11    6.17e-11
# ==============================================================================
# Omnibus:                     6139.090   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           110477.494
# Skew:                           4.032   Prob(JB):                         0.00
# Kurtosis:                      19.985   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Low Alpha Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Low Alpha   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.6442
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.422
# Time:                        14:05:52   Log-Likelihood:                          78798.
# No. Observations:                7500   AIC:                                 -1.576e+05
# Df Residuals:                    7499   BIC:                                 -1.576e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.417e-11   1.77e-11      0.803      0.422   -2.04e-11    4.88e-11
# ==============================================================================
# Omnibus:                    10049.809   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1523687.881
# Skew:                           7.876   Prob(JB):                         0.00
# Kurtosis:                      71.027   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# High Alpha Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             High Alpha   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.3164
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.574
# Time:                        14:05:52   Log-Likelihood:                          78265.
# No. Observations:                7500   AIC:                                 -1.565e+05
# Df Residuals:                    7499   BIC:                                 -1.565e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.066e-11    1.9e-11      0.562      0.574   -2.65e-11    4.78e-11
# ==============================================================================
# Omnibus:                    10107.126   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1577952.885
# Skew:                           7.949   Prob(JB):                         0.00
# Kurtosis:                      72.258   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Low Beta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Low Beta   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.1988
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.656
# Time:                        14:05:52   Log-Likelihood:                          77666.
# No. Observations:                7500   AIC:                                 -1.553e+05
# Df Residuals:                    7499   BIC:                                 -1.553e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          9.155e-12   2.05e-11      0.446      0.656   -3.11e-11    4.94e-11
# ==============================================================================
# Omnibus:                    10058.887   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1513252.162
# Skew:                           7.894   Prob(JB):                         0.00
# Kurtosis:                      70.773   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# High Beta Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              High Beta   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                            0.09779
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.755
# Time:                        14:05:52   Log-Likelihood:                          76707.
# No. Observations:                7500   AIC:                                 -1.534e+05
# Df Residuals:                    7499   BIC:                                 -1.534e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          7.297e-12   2.33e-11      0.313      0.755   -3.84e-11     5.3e-11
# ==============================================================================
# Omnibus:                    11597.910   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4113943.921
# Skew:                          10.017   Prob(JB):                         0.00
# Kurtosis:                     115.975   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Low Gamma Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Low Gamma   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                            0.01476
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.903
# Time:                        14:05:52   Log-Likelihood:                          74479.
# No. Observations:                7500   AIC:                                 -1.490e+05
# Df Residuals:                    7499   BIC:                                 -1.489e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          3.816e-12   3.14e-11      0.121      0.903   -5.78e-11    6.54e-11
# ==============================================================================
# Omnibus:                    13227.469   Durbin-Watson:                   0.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10900045.882
# Skew:                          12.792   Prob(JB):                         0.00
# Kurtosis:                     188.002   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
# Mid Gamma Model Summary
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Mid Gamma   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                           0.004267
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):                       0.948
# Time:                        14:05:52   Log-Likelihood:                          72854.
# No. Observations:                7500   AIC:                                 -1.457e+05
# Df Residuals:                    7499   BIC:                                 -1.457e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          2.548e-12    3.9e-11      0.065      0.948   -7.39e-11     7.9e-11
# ==============================================================================
# Omnibus:                    14485.518   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         21361444.027
# Skew:                          15.378   Prob(JB):                         0.00
# Kurtosis:                     262.636   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
search_df.to_csv('search_waves.csv')
found_df.to_csv('found_waves.csv')
